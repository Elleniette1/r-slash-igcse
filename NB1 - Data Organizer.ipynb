# %%
import paperparser
import os
import pandas as pd

# %%
bigdf = pd.DataFrame()
reada = os.listdir("thresholds/AL")
reada = [i for i in reada if not i.endswith(".xlsx")]
for foldername in reada:
    #print(foldername)
    df = pd.DataFrame()
    readfiles = os.listdir(f"thresholds/AL/{foldername}")
    readfiles = [i for i in readfiles if not i.endswith(".xlsx")]
    for filename in readfiles:
        #print(filename)
        df = pd.concat([df, paperparser.parse_threshold(f"./thresholds/AL/{foldername}/" + filename)[2]])
        df.to_excel(f"./thresholds/AL/{foldername}/{foldername}-thresholds.xlsx")
        df["subject"] = f"{foldername}"
    bigdf = pd.concat([bigdf, df])
    #display(df)
display(bigdf)
# Out:
#                   max mark   a*    a    b    c    d   e           date  \
# option
# AY 12,22,32              0  228  199  170  138  107  76     March 2022
# BY 32,88                 0  239  208  177  144  111  78     March 2022
# BYJ 32                   0  111   96   81   62   43  25     March 2022
# CY 32,98                 0  222  195  168  139  110  81     March 2022
# CYN 32                   0  111   96   81   62   43  25     March 2022
# ...                    ...  ...  ...  ...  ...  ...  ..            ...
# CZ2 43,53,99           260  211  187  163  136  110  84  November 2025
# EV 42,52,75            260  199  178  157  132  107  82  November 2025
# HC 14,24,38,44,54      260  214  190  166  138  110  83  November 2025
# HY 12,22,34,42,52      260  201  177  153  127  102  77  November 2025
# HZ 13,23,36,43,53      260  207  184  161  134  108  82  November 2025
#
#                       subject
# option
# AY 12,22,32        accounting
# BY 32,88           accounting
# BYJ 32             accounting
# CY 32,98           accounting
# CYN 32             accounting
# ...                       ...
# CZ2 43,53,99          physics
# EV 42,52,75           physics
# HC 14,24,38,44,54     physics
# HY 12,22,34,42,52     physics
# HZ 13,23,36,43,53     physics
#
# [1455 rows x 9 columns]

# %%
bigdf.to_excel("./thresholds/AL/al-thresholds.xlsx")

# %%
big2df = pd.DataFrame()
big91df = pd.DataFrame()
reada = os.listdir("thresholds/IGCSE")
reada = [i for i in reada if not i.endswith(".xlsx")]
for foldername in reada:
    #print(foldername)
    df = pd.DataFrame()
    readfiles = os.listdir(f"thresholds/IGCSE/{foldername}")
    readfiles = [i for i in readfiles if not i.endswith(".xlsx")]
    for filename in readfiles:
        #print(filename)
        df = pd.concat([df, paperparser.parse_threshold(f"./thresholds/IGCSE/{foldername}/" + filename)[2]])
        df.to_excel(f"./thresholds/IGCSE/{foldername}/{foldername}-thresholds.xlsx")
        df["subject"] = f"{foldername}"
    if "9-1" in foldername:
        big91df = pd.concat([big91df, df])
    else:
        big2df = pd.concat([big2df, df])
    #display(df)
display(big2df)
display(big91df)
# Out:
#             max mark   a*    a    b   c   d   e   f   g           date  \
# option
# AY 12,22           0  101   83   65  47  39  31  23  15     March 2022
# AX 11,21         143  100   80   60  40  34  29  24  19      June 2023
# AY 12,22         143  108   85   62  40  34  29  24  19      June 2023
# AZ 13,23         143  108   85   62  40  34  29  24  19      June 2023
# AX 11,21         143   93   74   55  37  31  26  21  16      June 2024
# ...              ...  ...  ...  ...  ..  ..  ..  ..  ..            ...
# BY 22,42,52      200  144  122  100  79  69  59  49  39  November 2024
# BZ 23,43,53      200  140  121  102  83  71  60  47  34  November 2024
# CX 21,41,61      200  138  117   96  76  65  54  44  34  November 2024
# CY 22,42,62      200  146  124  102  81  70  60  49  38  November 2024
# CZ 23,43,63      200  142  122  102  83  72  61  48  35  November 2024
#
#                 subject
# option
# AY 12,22     accounting
# AX 11,21     accounting
# AY 12,22     accounting
# AZ 13,23     accounting
# AX 11,21     accounting
# ...                 ...
# BY 22,42,52     physics
# BZ 23,43,53     physics
# CX 21,41,61     physics
# CY 22,42,62     physics
# CZ 23,43,63     physics
#
# [431 rows x 11 columns]
#             max mark    9    8    7    6   5   4   3   2   1           date  \
# option
# AX 11,21         143  110   95   80   66  53  40  33  26  19      June 2023
# AY 12,22         143  115  100   85   70  55  40  33  26  19      June 2023
# AX 11,21         143  108   91   74   61  49  37  30  23  16      June 2024
# AY 12,22         143  116  101   86   70  55  40  32  24  17      June 2024
# AX 11,21         143  110   94   79   66  53  40  32  24  17      June 2025
# ...              ...  ...  ...  ...  ...  ..  ..  ..  ..  ..            ...
# BX 21,41,51      200  151  137  123  107  91  75  65  55  46      June 2025
# CX 21,41,61      200  152  139  126  109  92  76  65  54  43      June 2025
# CY 22,42,62      200  156  142  128  111  94  78  64  50  37      June 2025
# BX 21,41,51      200  155  137  120  106  92  78  64  50  36  November 2024
# CX 21,41,61      200  153  135  117  103  89  76  62  48  34  November 2024
#
#                     subject
# option
# AX 11,21     accounting-9-1
# AY 12,22     accounting-9-1
# AX 11,21     accounting-9-1
# AY 12,22     accounting-9-1
# AX 11,21     accounting-9-1
# ...                     ...
# BX 21,41,51     physics-9-1
# CX 21,41,61     physics-9-1
# CY 22,42,62     physics-9-1
# BX 21,41,51     physics-9-1
# CX 21,41,61     physics-9-1
#
# [90 rows x 12 columns]

# %%
big2df.to_excel("./thresholds/IGCSE/igcse-thresholds.xlsx")
big91df.to_excel("./thresholds/IGCSE/igcse-9-1-thresholds.xlsx")
